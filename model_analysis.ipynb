# %%
import os
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import * 
from analysis.utils import *
from inference import load_dataset

# %%
log1d_paths = glob.glob('./logs/exp1d/*/*/*.csv')
log1d_df = load_accuracy_log(log1d_paths)
# Out:
# 100%|██████████| 18134/18134 [00:54<00:00, 335.60it/s]

# %%
log1d_df[(log1d_df.seed == 100) & (log1d_df.model == 'ft1d') & (log1d_df.dataset == 'cosine')].groupby(['resolution', 'coarse_level']).apply(lambda x : sorted(x.residual.unique()))
# Out:
# resolution  coarse_level
# 512         0                          [ml2, ml3, ml4, null]
#             1                    [diag, ml1, ml3, ml4, null]
#             2               [diag, ml1, ml2, ml3, ml4, null]
#             3               [diag, ml1, ml2, ml3, ml4, null]
#             4                     [diag, ml1, ml2, ml3, ml4]
# 1024        0               [diag, ml1, ml2, ml3, ml4, null]
#             1               [diag, ml1, ml2, ml3, ml4, null]
#             2               [diag, ml1, ml2, ml3, ml4, null]
#             3                    [diag, ml2, ml3, ml4, null]
#             4               [diag, ml1, ml2, ml3, ml4, null]
# 2048        0               [diag, ml1, ml2, ml3, ml4, null]
#             1               [diag, ml1, ml2, ml3, ml4, null]
#             2               [diag, ml1, ml2, ml3, ml4, null]
#             3               [diag, ml1, ml2, ml3, ml4, null]
#             4               [diag, ml1, ml2, ml3, ml4, null]
# ...
