# %%
import os
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import * 
from analysis.utils import *
from inference import load_dataset

# %%
log1d_paths = glob.glob('./logs/exp1d/*/*/*.csv')
log1d_df = load_accuracy_log(log1d_paths)
# Out:
# 100%|██████████| 18126/18126 [01:30<00:00, 201.33it/s]

# %%
log1d_df[(log1d_df.seed == 100) & (log1d_df.model == 'ft1d')].sort_values(['model', 'coarse_level', 'resolution']).head(10)
# Out:
#      model dataset  coarse_level  resolution residual  seed   test_l2  mcode
# 4835  ft1d   lnabs             0         512     diag   100  0.045587      0
# 4964  ft1d   lnabs             0         512      ml1   100  0.024543      1
# 5047  ft1d   lnabs             0         512      ml4   100  0.010801      4
# 5339  ft1d   lnabs             0         512      ml3   100  0.011402      3
# 5467  ft1d   lnabs             0         512     null   100  0.040628     -1
# ...    ...     ...           ...         ...      ...   ...       ...    ...
# 7388  ft1d  cosine             4        8192      ml2   100  0.017684      2
# 7548  ft1d  cosine             4        8192      ml4   100  0.019619      4
# 7759  ft1d  cosine             4        8192     diag   100  0.012020      0
# 7976  ft1d  cosine             4        8192      ml1   100  0.033381      1
# 8032  ft1d  cosine             4        8192     null   100  0.011854     -1
#
# [389 rows x 8 columns]
