# %%
import sys 
sys.path.append('../')

from dataset import load_dataset_1d
import scipy 
import matplotlib.pyplot as plt 
from einops import rearrange

# %%
data_root = '/workdir/pde_data/mlno/data1d'
task_nm = 'advection_diffusion_jump'
train_loader, test_loader = load_dataset_1d(task_nm, data_root)

# %%
us, ws = next(iter(train_loader))

# %%
us.shape
# Out:
# torch.Size([64, 1, 8192])

# %%
ws.shape
# Out:
# torch.Size([64, 1, 8192])

# %%
plt.plot(ws[0,0])

# %%
plt.plot(us[0,0])
