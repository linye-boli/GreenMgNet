# %%
import sys 
sys.path.append('../')

import torch 
from torchaudio.transforms import FFTConvolve
import torch.nn as nn
import torch.nn.functional as F

from model import MLP
import numpy as np
from utils import toeplitz_matrix_vector_multiplicaiton

# %%
l = 8
n = 2**l+1
x = torch.linspace(-1,1,2*n-1)[None][None]
u = torch.rand(n)[None][None]

# %%
u.shape
# Out:
# torch.Size([1, 1, 257])

# %%
x.shape
# Out:
# torch.Size([1, 1, 513])

# %%
neural_kernel = MLP([1,50,50,1], nn.ReLU)

# %%
k = neural_kernel(x)

# %%
toeplitz_matrix_vector_multiplicaiton(k, u).shape
# Out:
# torch.Size([1, 1, 257])
