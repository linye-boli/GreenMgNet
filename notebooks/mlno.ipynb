# %%
import sys 
sys.path.append('../')

import torch 
import torch.nn as nn
import torch.nn.functional as F

from model import MLNO

# %%
mlno = MLNO(1,1,6,1,16)
u = torch.rand((64, 1, 8192))
w = mlno(u)
