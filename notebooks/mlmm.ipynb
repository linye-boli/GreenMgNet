# %%
import sys 
sys.path.append('../')

# %%
import matplotlib.pyplot as plt

# %%
from benchmark.neuraloperator.utilities3 import * 
from mlmm import * 
from utils import *

# %%
sub = 1 
h = 2**13 // sub
s = h
ntrain = 1000
ntest = 200

# %%
dataloader = MatReader('/workdir/pde_data/data1d/burgers/burgers_data_R10.mat')

x_data = dataloader.read_field('a')[:,::sub]
y_data = dataloader.read_field('u')[:,::sub]

x_train = x_data[:ntrain,:]
y_train = y_data[:ntrain,:]
x_test = x_data[-ntest:,:]
y_test = y_data[-ntest:,:]
