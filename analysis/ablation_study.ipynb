# %%
import yaml
from easydict import EasyDict

# %%
with open('../cfgs/ablation.yaml') as f:
    ab_cfg = EasyDict(yaml.full_load(f))

# %%
ab_cfg.ca.clevel
# Out:
# [0, 1, 2, 3]

# %%
ab_cfg.mlevel
# Out:
# 0

# %%
ab_cfg['ca']
# Out:
# {'clevel': [0, 1, 2, 3], 'mlevel': 0, 'mw': 'same'}
