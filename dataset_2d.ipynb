# %%
from utils import MatReader
import scipy.io

# %%
data = scipy.io.loadmat('../pde_data/data2d/invdist_data.mat')

# %%
data['u'].shape
# Out:
# (2000, 421, 421)

# %%
data['a'].shape
# Out:
# (2000, 421, 421)
